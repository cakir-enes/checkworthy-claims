# %% [markdown]
# ### Location Variables

# %%
import os

data_dir = '~/Learn/ML/IR'
raw_data_dir = os.path.join(data_dir, 'raw')

# %% [markdown]
# ### Hyperparameters

# %%
maxlen = 300
embedding_dim = 300
seed = 7
n_splits = 8
epochs = 10
batch_size=10

# %% [markdown]
# ### Data Loading

# %%
import nltk
import re
WPT = nltk.WordPunctTokenizer()
stop_word_list = nltk.corpus.stopwords.words('turkish')

def norm_tweet(tweet):
    tweet = tweet.lower()
    pattern = r"[{}]".format(",.;@#!") 
    tweet = re.sub(pattern, "", str(tweet))
    tweet = tweet.strip()
    tokens = WPT.tokenize(tweet)
    filtered_tokens = [token for token in tokens if token not in stop_word_list]
    tweet = ' '.join(filtered_tokens)
    return tweet

def load_raw_data():
    from pandas import read_csv
    train_data = read_csv(os.path.join(raw_data_dir, 'train.csv'))
    test_data = read_csv(os.path.join(raw_data_dir, 'test.csv'))
    cols = ['tweet', 'has_claim', 'has_checkworthy_claim', 'obj_subj']
    train_data = train_data[cols]
    train_data = train_data.replace(['-'], '0')
    train_data = train_data.fillna('0')
    test_data =  test_data[cols]
    test_data =  test_data.replace(['-'], '0')
    test_data = test_data.fillna('0')
    return train_data, test_data

def drop_half(df, col, val):
    not_val = df.index[df[col] == val].to_list()
    df = df.drop(not_val[:int(len(not_val)/2)])
    return df

def load_data():
    train, test = load_raw_data()
    train['has_checkworthy_claim'] = train['has_checkworthy_claim'].map(lambda x: float(x))
    train['tweet'] = train['tweet'].map(norm_tweet)
    train = train.dropna()
    test['has_checkworthy_claim'] = test['has_checkworthy_claim'].map(lambda x: float(x))
    test['tweet'] = test['tweet'].map(norm_tweet)
    test = test.dropna()
    ## Drop half of the not checkworthy data since data is unbalanced
    train = drop_half(train, 'has_checkworthy_claim', 0)
    train = drop_half(train, 'has_checkworthy_claim', 0)
    test = drop_half(test, 'has_checkworthy_claim', 0)
    test = drop_half(test, 'has_checkworthy_claim', 0)
    
#     train = train.append(train.loc[train['has_checkworthy_claim'] == 1])
    return train, test

train_data, test_data = load_data()
num_of_check_worthy = lambda d: d[d['has_checkworthy_claim'] == 1]['has_checkworthy_claim'].sum() 
print('TRAIN DATA: Number of checkworthy claims: {} Number of not checkworthy claims: {}'.format(num_of_check_worthy(train_data), len(train_data) - num_of_check_worthy(train_data)))
print('TEST DATA: Number of checkworthy claims: {} Number of not checkworthy claims: {}'.format(num_of_check_worthy(test_data), len(test_data) - num_of_check_worthy(test_data)))
test_data.to_csv('testBalanced.csv', encoding='utf-8')
train_data.to_csv('trainBalanced.csv', encoding='utf-8')
# Out:
# TRAIN DATA: Number of checkworthy claims: 123.0 Number of not checkworthy claims: 154.0
# TEST DATA: Number of checkworthy claims: 36.0 Number of not checkworthy claims: 42.0

# %% [markdown]
# ### Plotting Helper

# %%
import matplotlib.pyplot as plt
plt.style.use('ggplot')
# %matplotlib inline
def plot_history(history, idx):
    acc = history.history['acc']
    val_acc = history.history['val_acc']
    loss = history.history['loss']
    val_loss = history.history['val_loss']
    x = range(1, len(acc) + 1)

    plt.figure(figsize=(12, 5))
    plt.subplot(1, 2, 1)
    plt.plot(x, acc, 'bo', label='Training acc')
    plt.plot(x, val_acc, 'r', label='Validation acc')
    plt.title('{}: Training and validation accuracy'.format(idx))
    plt.legend()
    plt.subplot(1, 2, 2)
    plt.plot(x, loss, 'bo', label='Training loss')
    plt.plot(x, val_loss, 'r', label='Validation loss')
    plt.title('{}: Training and validation loss'.format(idx))
    plt.legend()

# %% [markdown]
# ## Features & Pre Trained Word Embedding Matrix

# %%
from keras.preprocessing.text import Tokenizer
from keras.preprocessing.sequence import pad_sequences
import numpy as np
from flair.embeddings import WordEmbeddings, CharacterEmbeddings, StackedEmbeddings
from flair.data import Sentence, Token

np.random.seed(seed)

character_embeddings = CharacterEmbeddings()
fasttext_embedding = WordEmbeddings('tr-crawl')

stacked_embeddings = StackedEmbeddings(
    embeddings=[fasttext_embedding, character_embeddings])


def word_embedding(word):
    sentence = Sentence(word)
    stacked_embeddings.embed(sentence)
    return sentence[0].embedding.data

tokenizer = Tokenizer()
tokenizer.fit_on_texts(train_data['tweet'])
vocab_size = len(tokenizer.word_index) + 1

def create_embedding_matrix(embedder, word_index, embedding_dim):
    vocab_size = len(word_index) + 1
    embedding_matrix = np.zeros(((vocab_size, embedding_dim)))
    for word, idx in word_index.items():
        embedding_matrix[idx] = embedder(word)[:embedding_dim]
    return embedding_matrix

embedding_matrix = create_embedding_matrix(lambda w: word_embedding(w), tokenizer.word_index, embedding_dim)
# Out:
# Using TensorFlow backend.

# %% [markdown]
# ### Keras Model

# %%
from keras.layers import *
from keras.models import *
from keras import optimizers
import keras.regularizers
from keras.initializers import Constant

## Biderectional LSTM model also uses other features
def create_keras_model():
    nlp_input = Input(shape=(maxlen,), name='nlp_input')
    meta_input = Input(shape=(2,), name='meta_input')
    emb = Embedding(vocab_size, embedding_dim, input_length=maxlen, trainable=False, embeddings_initializer=Constant(embedding_matrix))(nlp_input)
    nlp_out = Bidirectional(LSTM(128, dropout=0.3, kernel_regularizer=regularizers.l2(0.01)))(emb)
    x = concatenate([nlp_out, meta_input])
    x = Dense(8, activation='relu')(x)
    x = Dense(1, activation='sigmoid')(x)
    model = Model(inputs=[nlp_input , meta_input], outputs=[x])
    model.compile(optimizer=optimizers.adam(),
                  loss='binary_crossentropy',
                  metrics=['accuracy'])
    return model

##  CNN Model 
def create_seq_model():
    model = Sequential()
    model.add(Embedding(vocab_size, embedding_dim, embeddings_initializer=Constant(embedding_matrix),input_length=maxlen, trainable=False))
    model.add(Conv1D(32, 5, activation='relu'))
    model.add(GlobalMaxPooling1D())
#     model.add(Dropout(0.5))
    model.add(Dense(10, activation='relu'))
    model.add(Dropout(0.2))
    model.add(Dense(1, activation='sigmoid'))
    model.compile(optimizer=optimizers.adam(),
                  loss='binary_crossentropy',
                  metrics=['accuracy'])
    return model

# %% [markdown]
# ## Cross Validation

# %%
from sklearn.model_selection import StratifiedKFold


X = train_data['tweet']
Y = train_data['has_checkworthy_claim']

kfold = StratifiedKFold(n_splits=n_splits, shuffle=True, random_state=seed)
cvscores = []
histories = []

for train, test in kfold.split(X, Y):
    model = create_keras_model()
#     model = create_seq_model()
    X_train = pad_sequences(tokenizer.texts_to_sequences(X.iloc[train]), padding='post', maxlen=maxlen)
    X_test = pad_sequences(tokenizer.texts_to_sequences(X.iloc[test]), padding='post', maxlen=maxlen)
    y_train = Y.iloc[train]
    y_test = Y.iloc[test]
    X_train_obj = train_data['obj_subj'].iloc[train]
    X_train_has_claim = train_data['has_claim'].iloc[train]
    X_test_obj = train_data['obj_subj'].iloc[test]
    X_test_has_claim = train_data['has_claim'].iloc[test]
    arr = np.array([X_train_obj, X_train_has_claim]).T
    arr_test = np.array([X_test_obj, X_test_has_claim]).T
#     print(arr.shape)
    history = model.fit([X_train, arr], y_train, epochs=epochs, validation_data=([X_test, arr_test], y_test), batch_size=batch_size, verbose=True)
#     history = model.fit(X_train, y_train, epochs=epochs, validation_data=(X_test, y_test), batch_size=batch_size, verbose=True)
    histories.append(history)
    scores = model.evaluate([X_test, arr_test], y_test, verbose=0)
#     scores = model.evaluate(X_test, y_test, verbose=0)
    print("%s: %.2f%%" % (model.metrics_names[1], scores[1]*100))
    cvscores.append(scores[1] * 100)
print("%.2f%% (+/- %.2f%%)" % (np.mean(cvscores), np.std(cvscores)))

for i, h in enumerate(histories):
    plot_history(h, i)
# Out:
# Train on 241 samples, validate on 36 samples
# Epoch 1/10
# 241/241 [==============================] - 9s 35ms/step - loss: 5.7853 - acc: 0.6432 - val_loss: 3.5606 - val_acc: 0.5556
# Epoch 2/10
# 241/241 [==============================] - 5s 21ms/step - loss: 2.4877 - acc: 0.6805 - val_loss: 1.5930 - val_acc: 0.6667
# Epoch 3/10
# 241/241 [==============================] - 5s 22ms/step - loss: 1.2127 - acc: 0.7261 - val_loss: 0.9283 - val_acc: 0.5833
# Epoch 4/10
# 241/241 [==============================] - 6s 27ms/step - loss: 0.8346 - acc: 0.7054 - val_loss: 0.7625 - val_acc: 0.5833
# Epoch 5/10
# 241/241 [==============================] - 8s 32ms/step - loss: 0.6798 - acc: 0.7012 - val_loss: 0.6591 - val_acc: 0.7222
# Epoch 6/10
# 241/241 [==============================] - 7s 28ms/step - loss: 0.5814 - acc: 0.7510 - val_loss: 0.6538 - val_acc: 0.7222
# Epoch 7/10
# 241/241 [==============================] - 7s 28ms/step - loss: 0.5737 - acc: 0.7635 - val_loss: 0.6716 - val_acc: 0.7500
# Epoch 8/10
# 241/241 [==============================] - 7s 27ms/step - loss: 0.6016 - acc: 0.7552 - val_loss: 0.6315 - val_acc: 0.7500
# Epoch 9/10
# 241/241 [==============================] - 7s 27ms/step - loss: 0.5733 - acc: 0.7676 - val_loss: 0.5909 - val_acc: 0.7778
# Epoch 10/10
# 241/241 [==============================] - 7s 28ms/step - loss: 0.5176 - acc: 0.8174 - val_loss: 0.8167 - val_acc: 0.7222
# acc: 72.22%
# Train on 241 samples, validate on 36 samples
# Epoch 1/10
# 241/241 [==============================] - 10s 41ms/step - loss: 5.8251 - acc: 0.5560 - val_loss: 3.5892 - val_acc: 0.5556
# Epoch 2/10
# 241/241 [==============================] - 6s 26ms/step - loss: 2.5048 - acc: 0.5560 - val_loss: 1.5960 - val_acc: 0.5556
# Epoch 3/10
# 241/241 [==============================] - 7s 29ms/step - loss: 1.2244 - acc: 0.5560 - val_loss: 0.9117 - val_acc: 0.5556
# Epoch 4/10
# 241/241 [==============================] - 7s 29ms/step - loss: 0.8144 - acc: 0.6639 - val_loss: 0.7297 - val_acc: 0.5833
# Epoch 5/10
# 241/241 [==============================] - 7s 28ms/step - loss: 0.6951 - acc: 0.6224 - val_loss: 0.6503 - val_acc: 0.6667
# Epoch 6/10
# 241/241 [==============================] - 7s 28ms/step - loss: 0.6411 - acc: 0.6888 - val_loss: 0.6226 - val_acc: 0.8056
# Epoch 7/10
# 241/241 [==============================] - 7s 29ms/step - loss: 0.6048 - acc: 0.7469 - val_loss: 0.5934 - val_acc: 0.8056
# Epoch 8/10
# 241/241 [==============================] - 7s 29ms/step - loss: 0.6164 - acc: 0.7510 - val_loss: 0.6157 - val_acc: 0.8333
# Epoch 9/10
# 241/241 [==============================] - 7s 28ms/step - loss: 0.6054 - acc: 0.7635 - val_loss: 0.5866 - val_acc: 0.6944
# Epoch 10/10
# 241/241 [==============================] - 7s 28ms/step - loss: 0.9992 - acc: 0.7137 - val_loss: 0.7326 - val_acc: 0.6944
# acc: 69.44%
# Train on 242 samples, validate on 35 samples
# Epoch 1/10
# 242/242 [==============================] - 10s 40ms/step - loss: 5.8564 - acc: 0.6116 - val_loss: 3.5767 - val_acc: 0.5714
# Epoch 2/10
# 242/242 [==============================] - 6s 27ms/step - loss: 2.4741 - acc: 0.6942 - val_loss: 1.5587 - val_acc: 0.6286
# Epoch 3/10
# 242/242 [==============================] - 6s 27ms/step - loss: 1.1837 - acc: 0.6818 - val_loss: 0.8566 - val_acc: 0.7429
# Epoch 4/10
# 242/242 [==============================] - 7s 27ms/step - loss: 0.7858 - acc: 0.6777 - val_loss: 0.6772 - val_acc: 0.8000
# Epoch 5/10
# 242/242 [==============================] - 7s 27ms/step - loss: 0.6719 - acc: 0.7355 - val_loss: 0.6236 - val_acc: 0.6286
# Epoch 6/10
# 242/242 [==============================] - 7s 28ms/step - loss: 0.6021 - acc: 0.7314 - val_loss: 0.6099 - val_acc: 0.6571
# Epoch 7/10
# 242/242 [==============================] - 7s 29ms/step - loss: 0.5858 - acc: 0.6901 - val_loss: 0.6172 - val_acc: 0.6857
# Epoch 8/10
# 242/242 [==============================] - 7s 28ms/step - loss: 0.5702 - acc: 0.7438 - val_loss: 0.6172 - val_acc: 0.6286
# Epoch 9/10
# 242/242 [==============================] - 7s 29ms/step - loss: 0.5583 - acc: 0.7769 - val_loss: 0.5823 - val_acc: 0.7143
# Epoch 10/10
# 242/242 [==============================] - 7s 28ms/step - loss: 0.5560 - acc: 0.7645 - val_loss: 0.5620 - val_acc: 0.8000
# acc: 80.00%
# Train on 243 samples, validate on 34 samples
# Epoch 1/10
# 243/243 [==============================] - 10s 40ms/step - loss: 5.8094 - acc: 0.7202 - val_loss: 3.5730 - val_acc: 0.7059
# Epoch 2/10
# 243/243 [==============================] - 7s 28ms/step - loss: 2.4854 - acc: 0.6955 - val_loss: 1.6546 - val_acc: 0.7353
# Epoch 3/10
# 243/243 [==============================] - 7s 28ms/step - loss: 1.2276 - acc: 0.7449 - val_loss: 0.9917 - val_acc: 0.7059
# Epoch 4/10
# 243/243 [==============================] - 7s 28ms/step - loss: 0.8126 - acc: 0.7572 - val_loss: 0.7323 - val_acc: 0.7059
# Epoch 5/10
# 243/243 [==============================] - 7s 27ms/step - loss: 0.6420 - acc: 0.7695 - val_loss: 0.6576 - val_acc: 0.7059
# Epoch 6/10
# 243/243 [==============================] - 7s 28ms/step - loss: 0.5692 - acc: 0.7819 - val_loss: 0.7225 - val_acc: 0.7353
# Epoch 7/10
# 243/243 [==============================] - 7s 29ms/step - loss: 0.5501 - acc: 0.7942 - val_loss: 0.6292 - val_acc: 0.7941
# Epoch 8/10
# 243/243 [==============================] - 7s 28ms/step - loss: 0.5344 - acc: 0.7737 - val_loss: 0.5900 - val_acc: 0.7647
# Epoch 9/10
# 243/243 [==============================] - 7s 29ms/step - loss: 0.4679 - acc: 0.8189 - val_loss: 0.5818 - val_acc: 0.8235
# Epoch 10/10
# 243/243 [==============================] - 7s 28ms/step - loss: 0.5241 - acc: 0.8313 - val_loss: 0.5714 - val_acc: 0.8824
# acc: 88.24%
# Train on 243 samples, validate on 34 samples
# Epoch 1/10
# 243/243 [==============================] - 11s 44ms/step - loss: 5.7790 - acc: 0.5967 - val_loss: 3.5790 - val_acc: 0.6471
# Epoch 2/10
# 243/243 [==============================] - 7s 28ms/step - loss: 2.4593 - acc: 0.6584 - val_loss: 1.6766 - val_acc: 0.6176
# Epoch 3/10
# 243/243 [==============================] - 7s 28ms/step - loss: 1.1740 - acc: 0.6996 - val_loss: 0.8949 - val_acc: 0.7059
# Epoch 4/10
# 243/243 [==============================] - 7s 28ms/step - loss: 0.7601 - acc: 0.7407 - val_loss: 0.7025 - val_acc: 0.6471
# Epoch 5/10
# 243/243 [==============================] - 7s 28ms/step - loss: 0.5940 - acc: 0.7695 - val_loss: 0.6663 - val_acc: 0.6176
# Epoch 6/10
# 243/243 [==============================] - 7s 27ms/step - loss: 0.5208 - acc: 0.8025 - val_loss: 0.7007 - val_acc: 0.6471
# Epoch 7/10
# 243/243 [==============================] - 7s 28ms/step - loss: 0.5970 - acc: 0.7572 - val_loss: 0.6867 - val_acc: 0.6765
# Epoch 8/10
# 243/243 [==============================] - 7s 28ms/step - loss: 0.5324 - acc: 0.8272 - val_loss: 0.6750 - val_acc: 0.7059
# Epoch 9/10
# 243/243 [==============================] - 6s 27ms/step - loss: 0.4620 - acc: 0.8395 - val_loss: 0.6213 - val_acc: 0.7941
# Epoch 10/10
# 243/243 [==============================] - 7s 28ms/step - loss: 0.5070 - acc: 0.8107 - val_loss: 0.6123 - val_acc: 0.7353
# acc: 73.53%
# Train on 243 samples, validate on 34 samples
# Epoch 1/10
# 243/243 [==============================] - 10s 39ms/step - loss: 5.7651 - acc: 0.5802 - val_loss: 3.5497 - val_acc: 0.6765
# Epoch 2/10
# 243/243 [==============================] - 6s 27ms/step - loss: 2.4632 - acc: 0.7078 - val_loss: 1.5745 - val_acc: 0.7059
# Epoch 3/10
# 243/243 [==============================] - 7s 27ms/step - loss: 1.1902 - acc: 0.7366 - val_loss: 0.8992 - val_acc: 0.6765
# Epoch 4/10
# 243/243 [==============================] - 6s 25ms/step - loss: 0.7741 - acc: 0.6955 - val_loss: 0.6831 - val_acc: 0.7059
# Epoch 5/10
# 243/243 [==============================] - 6s 25ms/step - loss: 0.6197 - acc: 0.7737 - val_loss: 0.6330 - val_acc: 0.6176
# Epoch 6/10
# 243/243 [==============================] - 6s 25ms/step - loss: 0.5858 - acc: 0.7778 - val_loss: 0.5653 - val_acc: 0.7059
# Epoch 7/10
# 243/243 [==============================] - 6s 25ms/step - loss: 0.5792 - acc: 0.7860 - val_loss: 0.5969 - val_acc: 0.7647
# Epoch 8/10
# 243/243 [==============================] - 6s 25ms/step - loss: 0.5240 - acc: 0.8230 - val_loss: 0.5868 - val_acc: 0.7647
# Epoch 9/10
# 243/243 [==============================] - 6s 25ms/step - loss: 0.5056 - acc: 0.8354 - val_loss: 0.6156 - val_acc: 0.7059
# Epoch 10/10
# 243/243 [==============================] - 6s 25ms/step - loss: 0.5151 - acc: 0.8066 - val_loss: 0.6253 - val_acc: 0.7059
# acc: 70.59%
# Train on 243 samples, validate on 34 samples
# Epoch 1/10
# 243/243 [==============================] - 10s 39ms/step - loss: 5.7832 - acc: 0.6296 - val_loss: 3.5751 - val_acc: 0.5588
# Epoch 2/10
# 243/243 [==============================] - 6s 26ms/step - loss: 2.4741 - acc: 0.6626 - val_loss: 1.6199 - val_acc: 0.5588
# Epoch 3/10
# 243/243 [==============================] - 7s 28ms/step - loss: 1.1696 - acc: 0.6996 - val_loss: 0.9442 - val_acc: 0.5882
# Epoch 4/10
# 243/243 [==============================] - 7s 28ms/step - loss: 0.7811 - acc: 0.7284 - val_loss: 0.7956 - val_acc: 0.6471
# Epoch 5/10
# 243/243 [==============================] - 8s 31ms/step - loss: 0.6653 - acc: 0.7407 - val_loss: 0.7427 - val_acc: 0.5882
# Epoch 6/10
# 243/243 [==============================] - 7s 28ms/step - loss: 0.5553 - acc: 0.7613 - val_loss: 0.6598 - val_acc: 0.6176
# Epoch 7/10
# 243/243 [==============================] - 7s 27ms/step - loss: 0.5447 - acc: 0.7942 - val_loss: 0.6752 - val_acc: 0.7647
# Epoch 8/10
# 243/243 [==============================] - 7s 27ms/step - loss: 0.4703 - acc: 0.8313 - val_loss: 0.8686 - val_acc: 0.6176
# Epoch 9/10
# 243/243 [==============================] - 7s 27ms/step - loss: 0.4341 - acc: 0.8683 - val_loss: 0.7699 - val_acc: 0.7059
# Epoch 10/10
# 243/243 [==============================] - 6s 27ms/step - loss: 0.4502 - acc: 0.8230 - val_loss: 0.7276 - val_acc: 0.6471
# acc: 64.71%
# Train on 243 samples, validate on 34 samples
# Epoch 1/10
# 243/243 [==============================] - 10s 43ms/step - loss: 5.7708 - acc: 0.5473 - val_loss: 3.5421 - val_acc: 0.8529
# Epoch 2/10
# 243/243 [==============================] - 6s 26ms/step - loss: 2.4654 - acc: 0.6708 - val_loss: 1.5730 - val_acc: 0.5882
# Epoch 3/10
# 243/243 [==============================] - 6s 26ms/step - loss: 1.1938 - acc: 0.6502 - val_loss: 0.8707 - val_acc: 0.7941
# Epoch 4/10
# 243/243 [==============================] - 6s 27ms/step - loss: 0.7600 - acc: 0.7037 - val_loss: 0.7151 - val_acc: 0.6765
# Epoch 5/10
# 243/243 [==============================] - 6s 27ms/step - loss: 0.6273 - acc: 0.7366 - val_loss: 0.6471 - val_acc: 0.7647
# Epoch 6/10
# 243/243 [==============================] - 6s 27ms/step - loss: 0.5642 - acc: 0.7449 - val_loss: 0.6175 - val_acc: 0.7353
# Epoch 7/10
# 243/243 [==============================] - 6s 26ms/step - loss: 0.5328 - acc: 0.8025 - val_loss: 0.6045 - val_acc: 0.7647
# Epoch 8/10
# 243/243 [==============================] - 6s 26ms/step - loss: 0.5126 - acc: 0.8066 - val_loss: 0.6787 - val_acc: 0.7353
# Epoch 9/10
# 243/243 [==============================] - 6s 26ms/step - loss: 0.4694 - acc: 0.8395 - val_loss: 0.7683 - val_acc: 0.6471
# Epoch 10/10
# 243/243 [==============================] - 6s 27ms/step - loss: 0.4983 - acc: 0.8107 - val_loss: 0.5643 - val_acc: 0.7941
# acc: 79.41%
# 74.77% (+/- 6.94%)

# %%
X_test = pad_sequences(tokenizer.texts_to_sequences(test_data['tweet']), padding='post', maxlen=maxlen)
X_test_obj = test_data['obj_subj']
X_test_has_claim = test_data['has_claim']
y_test = test_data['has_checkworthy_claim']
arr_test = np.array([X_test_obj, X_test_has_claim]).T
predicted = model.predict([X_test, arr_test])
scores = model.evaluate([X_test, arr_test], y_test, verbose=1)
# scores = model.evaluate(X_test, y_test, verbose=1)
# Out:
# 78/78 [==============================] - 0s 3ms/step

# %%
scores
# Out:
# [0.8004017220093653, 0.6282051297334524]

# %%
import pydot
from keras.utils import plot_model
plot_model(model, to_file='modelCNN.png')

# %%
from sklearn.metrics import confusion_matrix
matrix = confusion_matrix(y_test, list(map(lambda x: 1 if x > 0.5 else 0, model.predict([X_test, arr_test]))))

# %%
matrix
# Out:
# array([[34,  8],
#        [21, 15]])

# %%
from pandas_ml import ConfusionMatrix
cm = ConfusionMatrix(y_test.to_list(), list(map(lambda x: 1 if x > 0.5 else 0, predicted.reshape((78,)))))
cm.print_stats()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-1-577bf1962ef6> in <module>
#       1 from pandas_ml import ConfusionMatrix
# ----> 2 cm = ConfusionMatrix(y_test.to_list(), list(map(lambda x: 1 if x > 0.5 else 0, predicted.reshape((78,)))))
#       3 cm.print_stats()
#
# NameError: name 'y_test' is not defined

# %%
# Out:
# array([[0.80908775],
#        [0.02876422],
#        [0.32219774],
#        [0.48678118],
#        [0.73477775],
#        [0.49099353],
#        [0.23627505],
#        [0.8635146 ],
#        [0.15014094],
#        [0.06646982],
#        [0.42678732],
#        [0.5855154 ],
#        [0.3206321 ],
#        [0.15139735],
#        [0.43312693],
#        [0.43312693],
#        [0.9484948 ],
#        [0.8360257 ],
#        [0.11236477],
#        [0.7438222 ],
#        [0.07313746],
#        [0.2224479 ],
#        [0.03263557],
#        [0.0338555 ],
#        [0.08792314],
#        [0.858941  ],
#        [0.10710132],
#        [0.02818406],
#        [0.1562371 ],
#        [0.31466365],
#        [0.04819047],
#        [0.14731085],
#        [0.05399871],
#        [0.06817895],
#        [0.05498135],
#        [0.86281276],
#        [0.32687113],
#        [0.02724206],
#        [0.8273971 ],
#        [0.9279614 ],
#        [0.14104414],
#        [0.15032089],
#        [0.27132714],
#        [0.11255991],
#        [0.06772482],
#        [0.86544883],
#        [0.0796113 ],
#        [0.05346304],
#        [0.04240069],
#        [0.41806138],
#        [0.8604994 ],
#        [0.41571942],
#        [0.06006858],
#        [0.6145307 ],
#        [0.78268504],
#        [0.78132737],
#        [0.94627774],
#        [0.08225653],
#        [0.03763554],
#        [0.42415786],
#        [0.80418396],
#        [0.68138856],
#        [0.18535104],
#        [0.1158936 ],
#        [0.0307003 ],
#        [0.06654459],
#        [0.05413055],
#        [0.04320258],
#        [0.09643075],
#        [0.8327408 ],
#        [0.13090417],
#        [0.1397725 ],
#        [0.14784896],
#        [0.94661194],
#        [0.8772029 ],
#        [0.96329546],
#        [0.09044202],
#        [0.08325576]], dtype=float32)
